# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
Savee = "C:/Users/ADMIN/data/SAVEE/ALL/"

# %%
savee_directory_list = os.listdir(Savee)

file_emotion = []
file_path = []

for file in savee_directory_list:
    file_path.append(Savee + file)
    part = file.split('_')[1]
    ele = part[:-6]
    if ele=='a':
        file_emotion.append('angry')
    elif ele=='d':
        file_emotion.append('disgust')
    elif ele=='f':
        file_emotion.append('fear')
    elif ele=='h':
        file_emotion.append('happy')
    elif ele=='n':
        file_emotion.append('neutral')
    elif ele=='sa':
        file_emotion.append('sad')
    else:
        file_emotion.append('surprise')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head()
# Out:
#   Emotions                                      Path
# 0    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a01.wav
# 1    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a02.wav
# 2    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a03.wav
# 3    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a04.wav
# 4    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a05.wav

# %%
# creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([Savee_df], axis = 0)
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                      Path
# 0    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a01.wav
# 1    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a02.wav
# 2    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a03.wav
# 3    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a04.wav
# 4    angry  C:/Users/ADMIN/data/SAVEE/ALL/DC_a05.wav

# %%
plt.title('Count of Emotions', size=16)
sns.countplot(data_path.Emotions)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveplot(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %%
emotion='fear'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='angry'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='sad'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='happy'
path = np.array(data_path.Path[data_path.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# taking any example and checking for techniques.
path = np.array(data_path.Path)[1]
data, sample_rate = librosa.load(path)

# %%
plt.figure(figsize=(14,4))
librosa.display.waveplot(y=data, sr=sample_rate)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = noise(data)
plt.figure(figsize=(14,4))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = stretch(data)
plt.figure(figsize=(14,4))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = shift(data)
plt.figure(figsize=(14,4))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = pitch(data, sample_rate)
plt.figure(figsize=(14,4))
librosa.display.waveplot(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_features(data):
    # ZCR
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally
    
    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2)) # stacking vertically
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
X, Y = [], []
for path, emotion in zip(data_path.Path, data_path.Emotions):
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
        Y.append(emotion)

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (1440, 1440, (480,))

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('features.csv', index=False)
Features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.038891  0.470030  0.577977  0.554338  0.482513  0.459260  0.483099
# 1  0.040328  0.484380  0.593669  0.570279  0.500618  0.476909  0.494398
# 2  0.032809  0.358430  0.503856  0.616875  0.561644  0.449105  0.437660
# 3  0.033904  0.657557  0.696857  0.616553  0.544234  0.478499  0.445451
# 4  0.051527  0.656619  0.761780  0.749118  0.673630  0.596741  0.525747
#
#           7         8         9  ...       153       154       155       156  \
# 0  0.504528  0.459470  0.537165  ...  0.000008  0.000002  0.000002  0.000002
# 1  0.509507  0.469973  0.545940  ...  0.000448  0.000449  0.000480  0.000459
# 2  0.474675  0.471159  0.439713  ...  0.000014  0.000008  0.000005  0.000005
# 3  0.418413  0.456779  0.550003  ...  0.000054  0.000058  0.000068  0.000079
# 4  0.476165  0.488172  0.577552  ...  0.012940  0.013656  0.013521  0.013889
#
#         157       158       159       160       161  labels
# 0  0.000002  0.000003  0.000004  0.000006  0.000006   angry
# 1  0.000450  0.000438  0.000476  0.000473  0.000453   angry
# 2  0.000005  0.000006  0.000008  0.000011  0.000012   angry
# 3  0.000093  0.000126  0.000195  0.000324  0.000382   angry
# 4  0.013286  0.013090  0.014040  0.013877  0.013543   angry
#
# [5 rows x 163 columns]

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 162), (1080, 7), (360, 162), (360, 7))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 162), (1080, 7), (360, 162), (360, 7))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1080, 162, 1), (1080, 7), (360, 162, 1), (360, 7))

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=7, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 162, 256)          1536
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 81, 256)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 81, 256)           327936
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 41, 256)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 41, 128)           163968
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 21, 128)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 21, 128)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 21, 64)            41024
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 11, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 704)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                22560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 557,255
# Trainable params: 557,255
# Non-trainable params: 0
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 135/135 [==============================] - 6s 41ms/step - loss: 1.8476 - accuracy: 0.2778 - val_loss: 1.7494 - val_accuracy: 0.3750
# Epoch 2/50
# 135/135 [==============================] - 5s 39ms/step - loss: 1.6969 - accuracy: 0.3407 - val_loss: 1.5672 - val_accuracy: 0.4056
# Epoch 3/50
# 135/135 [==============================] - 6s 41ms/step - loss: 1.6155 - accuracy: 0.3361 - val_loss: 1.4928 - val_accuracy: 0.4111
# Epoch 4/50
# 135/135 [==============================] - 6s 41ms/step - loss: 1.5840 - accuracy: 0.3500 - val_loss: 1.4719 - val_accuracy: 0.4000
# Epoch 5/50
# 135/135 [==============================] - 6s 42ms/step - loss: 1.5115 - accuracy: 0.3759 - val_loss: 1.4526 - val_accuracy: 0.4306
# Epoch 6/50
# 135/135 [==============================] - 7s 53ms/step - loss: 1.5068 - accuracy: 0.3630 - val_loss: 1.4108 - val_accuracy: 0.4306
# Epoch 7/50
# 135/135 [==============================] - 9s 66ms/step - loss: 1.4224 - accuracy: 0.4000 - val_loss: 1.3123 - val_accuracy: 0.4639
# Epoch 8/50
# 135/135 [==============================] - 9s 67ms/step - loss: 1.4086 - accuracy: 0.4287 - val_loss: 1.3157 - val_accuracy: 0.4667
# Epoch 9/50
# 135/135 [==============================] - 9s 66ms/step - loss: 1.3575 - accuracy: 0.4259 - val_loss: 1.3793 - val_accuracy: 0.4194
# Epoch 10/50
# 135/135 [==============================] - 9s 66ms/step - loss: 1.3528 - accuracy: 0.4296 - val_loss: 1.2185 - val_accuracy: 0.4861
# Epoch 11/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.2811 - accuracy: 0.4685 - val_loss: 1.1632 - val_accuracy: 0.5361
# Epoch 12/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.2125 - accuracy: 0.4833 - val_loss: 1.1700 - val_accuracy: 0.5222
# Epoch 13/50
# 135/135 [==============================] - 9s 66ms/step - loss: 1.1798 - accuracy: 0.5037 - val_loss: 1.1900 - val_accuracy: 0.5111
# Epoch 14/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.1787 - accuracy: 0.4926 - val_loss: 1.1363 - val_accuracy: 0.5583
# Epoch 15/50
# 135/135 [==============================] - 9s 66ms/step - loss: 1.1503 - accuracy: 0.5102 - val_loss: 1.1923 - val_accuracy: 0.5333
# Epoch 16/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.1105 - accuracy: 0.5046 - val_loss: 1.1642 - val_accuracy: 0.5278
# Epoch 17/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.0713 - accuracy: 0.5370 - val_loss: 1.0493 - val_accuracy: 0.5639
# Epoch 18/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.0707 - accuracy: 0.5509 - val_loss: 1.0255 - val_accuracy: 0.5806
# Epoch 19/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.0237 - accuracy: 0.5676 - val_loss: 1.0253 - val_accuracy: 0.5667
# Epoch 20/50
# 135/135 [==============================] - 9s 65ms/step - loss: 1.0337 - accuracy: 0.5574 - val_loss: 1.0708 - val_accuracy: 0.5611
# Epoch 21/50
# 135/135 [==============================] - 8s 63ms/step - loss: 0.9929 - accuracy: 0.5630 - val_loss: 1.0424 - val_accuracy: 0.5806
# Epoch 22/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.9577 - accuracy: 0.6000 - val_loss: 1.0144 - val_accuracy: 0.6000
# Epoch 23/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.9532 - accuracy: 0.5935 - val_loss: 1.0871 - val_accuracy: 0.5500
# Epoch 24/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.9222 - accuracy: 0.6074 - val_loss: 1.0759 - val_accuracy: 0.55839346 -
# Epoch 25/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.8583 - accuracy: 0.6333 - val_loss: 1.0926 - val_accuracy: 0.6000
# Epoch 26/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.8586 - accuracy: 0.6278 - val_loss: 1.0751 - val_accuracy: 0.6000
# Epoch 27/50
# 135/135 [==============================] - 9s 63ms/step - loss: 0.8565 - accuracy: 0.6278 - val_loss: 0.9731 - val_accuracy: 0.6000
# Epoch 28/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.8132 - accuracy: 0.6481 - val_loss: 1.1100 - val_accuracy: 0.6139
# Epoch 29/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.7833 - accuracy: 0.6704 - val_loss: 1.0030 - val_accuracy: 0.6111
# Epoch 30/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.7861 - accuracy: 0.6565 - val_loss: 1.1277 - val_accuracy: 0.6139
# Epoch 31/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.8256 - accuracy: 0.6528 - val_loss: 1.0000 - val_accuracy: 0.6111
# Epoch 32/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.6960 - accuracy: 0.7065 - val_loss: 0.9544 - val_accuracy: 0.6389
# Epoch 33/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.5995 - accuracy: 0.7352 - val_loss: 0.9686 - val_accuracy: 0.6611
# Epoch 34/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.6222 - accuracy: 0.7231 - val_loss: 0.9563 - val_accuracy: 0.6500
# Epoch 35/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.5650 - accuracy: 0.7630 - val_loss: 1.0386 - val_accuracy: 0.6583
# Epoch 36/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.5602 - accuracy: 0.7454 - val_loss: 1.0264 - val_accuracy: 0.6361
# Epoch 37/50
# 135/135 [==============================] - 8s 63ms/step - loss: 0.5492 - accuracy: 0.7620 - val_loss: 0.9840 - val_accuracy: 0.6611
# Epoch 38/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.5544 - accuracy: 0.7648 - val_loss: 1.0061 - val_accuracy: 0.6583
# Epoch 39/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.5243 - accuracy: 0.7694 - val_loss: 1.0431 - val_accuracy: 0.6528
# Epoch 40/50
# 135/135 [==============================] - 8s 63ms/step - loss: 0.4945 - accuracy: 0.7843 - val_loss: 1.0278 - val_accuracy: 0.6611
# Epoch 41/50
# 135/135 [==============================] - 9s 63ms/step - loss: 0.5293 - accuracy: 0.7639 - val_loss: 1.0645 - val_accuracy: 0.6528
# Epoch 42/50
# 135/135 [==============================] - 9s 64ms/step - loss: 0.4971 - accuracy: 0.7843 - val_loss: 1.1080 - val_accuracy: 0.6528
# Epoch 43/50
# 135/135 [==============================] - 9s 65ms/step - loss: 0.4686 - accuracy: 0.7870 - val_loss: 1.0281 - val_accuracy: 0.6639
# Epoch 44/50
# 135/135 [==============================] - 9s 63ms/step - loss: 0.4352 - accuracy: 0.8120 - val_loss: 1.0508 - val_accuracy: 0.6500
# Epoch 45/50
# 135/135 [==============================] - 9s 63ms/step - loss: 0.4184 - accuracy: 0.8241 - val_loss: 1.0868 - val_accuracy: 0.6583
# Epoch 46/50
# 135/135 [==============================] - 9s 63ms/step - loss: 0.4485 - accuracy: 0.7981 - val_loss: 1.0795 - val_accuracy: 0.6472
# Epoch 47/50
# 135/135 [==============================] - 8s 63ms/step - loss: 0.4115 - accuracy: 0.8231 - val_loss: 1.1093 - val_accuracy: 0.6639
# Epoch 48/50
# 135/135 [==============================] - 9s 63ms/step - loss: 0.3999 - accuracy: 0.8259 - val_loss: 1.1066 - val_accuracy: 0.6639
# Epoch 49/50
# 135/135 [==============================] - 8s 63ms/step - loss: 0.4080 - accuracy: 0.8250 - val_loss: 1.1084 - val_accuracy: 0.6556
# Epoch 50/50
# 135/135 [==============================] - 8s 63ms/step - loss: 0.3992 - accuracy: 0.8306 - val_loss: 1.0825 - val_accuracy: 0.6833

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 12/12 [==============================] - 0s 40ms/step - loss: 1.0825 - accuracy: 0.6833
# Accuracy of our model on test data :  68.33333373069763 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            angry         angry
# 1         surprise      surprise
# 2         surprise         happy
# 3            angry      surprise
# 4            happy         happy
# 5            angry         angry
# 6              sad       neutral
# 7              sad           sad
# 8            happy          fear
# 9          disgust       disgust

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.87      0.60      0.71        43
#      disgust       0.58      0.67      0.62        45
#         fear       0.64      0.56      0.60        41
#        happy       0.64      0.64      0.64        42
#      neutral       0.76      0.86      0.80        98
#          sad       0.76      0.54      0.63        52
#     surprise       0.54      0.72      0.62        39
#
#     accuracy                           0.68       360
#    macro avg       0.68      0.66      0.66       360
# weighted avg       0.70      0.68      0.68       360
